# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\ANSHIKA\Downloads\c1f5fb48-ba6c-4464-919d-4aba384c7c80.xlsx")
df
# Out:
#     EmployeeID      Name     Age  Gender Department  Salary       City  \
# 0         1001     Rahul      22  Female        NaN   55000  Bangalore
# 1         1002     Kiran      31       M  Marketing     NaN    Calicut
# 2         1003       Anu  Thirty       F      Sales  48,000        NaN
# 3         1004      John      27       F  Marketing   35000    Calicut
# 4         1005     Aisha      25     NaN         IT  48,000        NaN
# ..         ...       ...     ...     ...        ...     ...        ...
# 95        1096       Anu      27    Male      Sales   42000      kochi
# 96        1097  Mohammed      29    Male         HR   35000        NaN
# 97        1098       Anu      22    Male         HR     NaN        NaN
# 98        1099     Arun       22  Female         IT   42000      Kochi
# 99        1100      Sara      31  Female        IT    55000        NaN
#
#       JoinDate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df.head(10)
# Out:
#    EmployeeID       Name     Age  Gender Department  Salary       City  \
# 0        1001      Rahul      22  Female        NaN   55000  Bangalore
# 1        1002      Kiran      31       M  Marketing     NaN    Calicut
# 2        1003        Anu  Thirty       F      Sales  48,000        NaN
# 3        1004       John      27       F  Marketing   35000    Calicut
# 4        1005      Aisha      25     NaN         IT  48,000        NaN
# 5        1006      Deepa      27       F         HR  48,000        NaN
# 6        1007      Priya  Thirty     NaN        NaN     NaN  Bangalore
# 7        1008      Aisha      27     NaN  Marketing  48,000        NaN
# 8        1009  Mohammed      NaN       M        NaN   55000        NaN
# 9        1010   Mohammed      25       F         HR  48,000  Bangalore
#
#      JoinDate Performance             Email
# 0         NaN       good     test@mail.com
# 1  2023-01-15         NaN      invalidemail
# 2         NaN        Good    test@mail.com
# ...

# %%
df.tail(10)
# Out:
#     EmployeeID      Name     Age  Gender Department  Salary     City  \
# 90        1091     Aisha      22       M      Sales   35000  Calicut
# 91        1092     Kiran     NaN       F    Finance   55000      NaN
# 92        1093  Mohammed  Thirty    Male        NaN   55000    Kochi
# 93        1094      Arun      22       F      Sales   35000  Calicut
# 94        1095     Deepa      25    Male  Marketing  48,000      NaN
# 95        1096       Anu      27    Male      Sales   42000    kochi
# 96        1097  Mohammed      29    Male         HR   35000      NaN
# 97        1098       Anu      22    Male         HR     NaN      NaN
# 98        1099     Arun       22  Female         IT   42000    Kochi
# 99        1100      Sara      31  Female        IT    55000      NaN
#
#       JoinDate Performance             Email
# 90  15/02/2022       good       invalidemail
# 91         NaN        Poor  user@example.com
# 92         NaN        Good               NaN
# ...

# %%
df.describe()
# Out:
#         EmployeeID
# count   100.000000
# mean   1050.400000
# std      29.151988
# min    1001.000000
# 25%    1025.750000
# 50%    1050.500000
# 75%    1075.250000
# max    1100.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   100 non-null    int64
#  1   Name         100 non-null    str
#  2   Age          82 non-null     object
#  3   Gender       75 non-null     str
#  4   Department   85 non-null     str
#  5   Salary       77 non-null     object
#  6   City         70 non-null     str
#  7   JoinDate     83 non-null     str
#  8   Performance  81 non-null     str
#  9   Email        75 non-null     str
# dtypes: int64(1), object(2), str(7)
# memory usage: 7.9+ KB

# %%
df.nunique()
# Out:
# EmployeeID     99
# Name           18
# Age             6
# Gender          4
# Department      6
# Salary          4
# City            5
# JoinDate        3
# Performance     4
# Email           3
# dtype: int64

# %%
df.isnull()
# Out:
#     EmployeeID   Name    Age  Gender  Department  Salary   City  JoinDate  \
# 0        False  False  False   False        True   False  False      True
# 1        False  False  False   False       False    True  False     False
# 2        False  False  False   False       False   False   True      True
# 3        False  False  False   False       False   False  False     False
# 4        False  False  False    True       False   False   True     False
# ..         ...    ...    ...     ...         ...     ...    ...       ...
# 95       False  False  False   False       False   False  False     False
# 96       False  False  False   False       False   False   True     False
# 97       False  False  False   False       False    True   True      True
# 98       False  False  False   False       False   False  False     False
# 99       False  False  False   False       False   False   True     False
#
#     Performance  Email
# 0         False  False
# 1          True  False
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.duplicated("EmployeeID")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.columns=df.columns.str.lower()
df
# Out:
#     e   m   p   l   o   y   e   e   i   d    n   a   m   e    a   g   e     \
# 0                                       1001            Rahul           22
# 1                                       1002            Kiran           31
# 2                                       1003              Anu       Thirty
# 3                                       1004             John           27
# 4                                       1005            Aisha           25
# ..                                       ...              ...          ...
# 95                                      1096              Anu           27
# 96                                      1097         Mohammed           29
# 97                                      1098              Anu           22
# 98                                      1099            Arun            22
# 99                                      1100             Sara           31
#
# ...

# %%
print(df.columns)
# Out:
# Index(['   e   m   p   l   o   y   e   e   i   d   ', '   n   a   m   e   ',
#        '   a   g   e   ', '   g   e   n   d   e   r   ',
#        '   d   e   p   a   r   t   m   e   n   t   ',
#        '   s   a   l   a   r   y   ', '   c   i   t   y   ',
#        '   j   o   i   n   d   a   t   e   ',
#        '   p   e   r   f   o   r   m   a   n   c   e   ',
#        '   e   m   a   i   l   '],
#       dtype='str')

# %%
print(repr(df.columns[0]))
# Out:
# '   e   m   p   l   o   y   e   e   i   d   '

# %%
df.columns = [''.join(col.split()) for col in df.columns]

# %%
df
# Out:
#     employeeid      name     age  gender department  salary       city  \
# 0         1001     Rahul      22  Female        NaN   55000  Bangalore
# 1         1002     Kiran      31       M  Marketing     NaN    Calicut
# 2         1003       Anu  Thirty       F      Sales  48,000        NaN
# 3         1004      John      27       F  Marketing   35000    Calicut
# 4         1005     Aisha      25     NaN         IT  48,000        NaN
# ..         ...       ...     ...     ...        ...     ...        ...
# 95        1096       Anu      27    Male      Sales   42000      kochi
# 96        1097  Mohammed      29    Male         HR   35000        NaN
# 97        1098       Anu      22    Male         HR     NaN        NaN
# 98        1099     Arun       22  Female         IT   42000      Kochi
# 99        1100      Sara      31  Female        IT    55000        NaN
#
#       joindate performance             email
# 0          NaN       good     test@mail.com
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_", regex=False)
df
# Out:
#     employeeid      name     age  gender department  salary       city  \
# 0         1001     Rahul      22  Female        NaN   55000  Bangalore
# 1         1002     Kiran      31       M  Marketing     NaN    Calicut
# 2         1003       Anu  Thirty       F      Sales  48,000        NaN
# 3         1004      John      27       F  Marketing   35000    Calicut
# 4         1005     Aisha      25     NaN         IT  48,000        NaN
# ..         ...       ...     ...     ...        ...     ...        ...
# 95        1096       Anu      27    Male      Sales   42000      kochi
# 96        1097  Mohammed      29    Male         HR   35000        NaN
# 97        1098       Anu      22    Male         HR     NaN        NaN
# 98        1099     Arun       22  Female         IT   42000      Kochi
# 99        1100      Sara      31  Female        IT    55000        NaN
#
#       joindate performance             email
# 0          NaN       good     test@mail.com
# ...

# %%
df.rename(columns={"employeeid": "Employee_Id"}, inplace=True)
df
# Out:
#     Employee_Id      name     age  gender department  salary       city  \
# 0          1001     Rahul      22  Female        NaN   55000  Bangalore
# 1          1002     Kiran      31       M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty       F      Sales  48,000        NaN
# 3          1004      John      27       F  Marketing   35000    Calicut
# 4          1005     Aisha      25     NaN         IT  48,000        NaN
# ..          ...       ...     ...     ...        ...     ...        ...
# 95         1096       Anu      27    Male      Sales   42000      kochi
# 96         1097  Mohammed      29    Male         HR   35000        NaN
# 97         1098       Anu      22    Male         HR     NaN        NaN
# 98         1099     Arun       22  Female         IT   42000      Kochi
# 99         1100      Sara      31  Female        IT    55000        NaN
#
#       joindate performance             email
# 0          NaN       good     test@mail.com
# ...

# %%
df.rename(columns={"joindate": "Join Date"})
df
# Out:
#     Employee_Id      name     age  gender department  salary       city  \
# 0          1001     Rahul      22  Female        NaN   55000  Bangalore
# 1          1002     Kiran      31       M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty       F      Sales  48,000        NaN
# 3          1004      John      27       F  Marketing   35000    Calicut
# 4          1005     Aisha      25     NaN         IT  48,000        NaN
# ..          ...       ...     ...     ...        ...     ...        ...
# 95         1096       Anu      27    Male      Sales   42000      kochi
# 96         1097  Mohammed      29    Male         HR   35000        NaN
# 97         1098       Anu      22    Male         HR     NaN        NaN
# 98         1099     Arun       22  Female         IT   42000      Kochi
# 99         1100      Sara      31  Female        IT    55000        NaN
#
#       joindate performance             email
# 0          NaN       good     test@mail.com
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
#     Employee_Id      name     age  gender department  salary       city  \
# 0          1001     Rahul      22  Female        NaN   55000  Bangalore
# 1          1002     Kiran      31       M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty       F      Sales  48,000        NaN
# 3          1004      John      27       F  Marketing   35000    Calicut
# 4          1005     Aisha      25     NaN         IT  48,000        NaN
# ..          ...       ...     ...     ...        ...     ...        ...
# 95         1096       Anu      27    Male      Sales   42000      kochi
# 96         1097  Mohammed      29    Male         HR   35000        NaN
# 97         1098       Anu      22    Male         HR     NaN        NaN
# 98         1099     Arun       22  Female         IT   42000      Kochi
# 99         1100      Sara      31  Female        IT    55000        NaN
#
#       joindate performance             email
# 0          NaN       good     test@mail.com
# ...

# %%
df.columns=df.columns.str.title()
df
# Out:
#     Employee_Id      Name     Age  Gender Department  Salary       City  \
# 0          1001     Rahul      22  Female        NaN   55000  Bangalore
# 1          1002     Kiran      31       M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty       F      Sales  48,000        NaN
# 3          1004      John      27       F  Marketing   35000    Calicut
# 4          1005     Aisha      25     NaN         IT  48,000        NaN
# ..          ...       ...     ...     ...        ...     ...        ...
# 95         1096       Anu      27    Male      Sales   42000      kochi
# 96         1097  Mohammed      29    Male         HR   35000        NaN
# 97         1098       Anu      22    Male         HR     NaN        NaN
# 98         1099     Arun       22  Female         IT   42000      Kochi
# 99         1100      Sara      31  Female        IT    55000        NaN
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Id     0
# Name            0
# Age            18
# Gender         25
# Department     15
# Salary         23
# City           30
# Joindate       17
# Performance    19
# Email          25
# dtype: int64

# %%
df.dtypes
# Out:
# Employee_Id     int64
# Name              str
# Age            object
# Gender            str
# Department        str
# Salary         object
# City              str
# Joindate          str
# Performance       str
# Email             str
# dtype: object

# %%
df["Gender"] = df["Gender"].fillna("Unknown")
df
# Out:
#     Employee_Id      Name     Age   Gender Department  Salary       City  \
# 0          1001     Rahul      22   Female        NaN   55000  Bangalore
# 1          1002     Kiran      31        M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty        F      Sales  48,000        NaN
# 3          1004      John      27        F  Marketing   35000    Calicut
# 4          1005     Aisha      25  Unknown         IT  48,000        NaN
# ..          ...       ...     ...      ...        ...     ...        ...
# 95         1096       Anu      27     Male      Sales   42000      kochi
# 96         1097  Mohammed      29     Male         HR   35000        NaN
# 97         1098       Anu      22     Male         HR     NaN        NaN
# 98         1099     Arun       22   Female         IT   42000      Kochi
# 99         1100      Sara      31   Female        IT    55000        NaN
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Department"] = df["Department"].fillna("Unknown")
df
# Out:
#     Employee_Id      Name     Age   Gender Department  Salary       City  \
# 0          1001     Rahul      22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran      31        M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty        F      Sales  48,000        NaN
# 3          1004      John      27        F  Marketing   35000    Calicut
# 4          1005     Aisha      25  Unknown         IT  48,000        NaN
# ..          ...       ...     ...      ...        ...     ...        ...
# 95         1096       Anu      27     Male      Sales   42000      kochi
# 96         1097  Mohammed      29     Male         HR   35000        NaN
# 97         1098       Anu      22     Male         HR     NaN        NaN
# 98         1099     Arun       22   Female         IT   42000      Kochi
# 99         1100      Sara      31   Female        IT    55000        NaN
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Salary"].dtype
# Out:
# dtype('O')

# %%
df["Salary"].unique()
# Out:
# array([55000, nan, '48,000', 35000, 42000], dtype=object)

# %%
df["City"] = df["City"].fillna("Unknown")
df
# Out:
#     Employee_Id      Name     Age   Gender Department  Salary       City  \
# 0          1001     Rahul      22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran      31        M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty        F      Sales  48,000    Unknown
# 3          1004      John      27        F  Marketing   35000    Calicut
# 4          1005     Aisha      25  Unknown         IT  48,000    Unknown
# ..          ...       ...     ...      ...        ...     ...        ...
# 95         1096       Anu      27     Male      Sales   42000      kochi
# 96         1097  Mohammed      29     Male         HR   35000    Unknown
# 97         1098       Anu      22     Male         HR     NaN    Unknown
# 98         1099     Arun       22   Female         IT   42000      Kochi
# 99         1100      Sara      31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Performance"] = df["Performance"].fillna("Unknown")
df
# Out:
#     Employee_Id      Name     Age   Gender Department  Salary       City  \
# 0          1001     Rahul      22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran      31        M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty        F      Sales  48,000    Unknown
# 3          1004      John      27        F  Marketing   35000    Calicut
# 4          1005     Aisha      25  Unknown         IT  48,000    Unknown
# ..          ...       ...     ...      ...        ...     ...        ...
# 95         1096       Anu      27     Male      Sales   42000      kochi
# 96         1097  Mohammed      29     Male         HR   35000    Unknown
# 97         1098       Anu      22     Male         HR     NaN    Unknown
# 98         1099     Arun       22   Female         IT   42000      Kochi
# 99         1100      Sara      31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Email"] = df["Email"].fillna("Unknown")
df
# Out:
#     Employee_Id      Name     Age   Gender Department  Salary       City  \
# 0          1001     Rahul      22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran      31        M  Marketing     NaN    Calicut
# 2          1003       Anu  Thirty        F      Sales  48,000    Unknown
# 3          1004      John      27        F  Marketing   35000    Calicut
# 4          1005     Aisha      25  Unknown         IT  48,000    Unknown
# ..          ...       ...     ...      ...        ...     ...        ...
# 95         1096       Anu      27     Male      Sales   42000      kochi
# 96         1097  Mohammed      29     Male         HR   35000    Unknown
# 97         1098       Anu      22     Male         HR     NaN    Unknown
# 98         1099     Arun       22   Female         IT   42000      Kochi
# 99         1100      Sara      31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Age"] = df["Age"].replace("Thirty", 30)
# Out:
#     Employee_Id      Name Age   Gender Department  Salary       City  \
# 0          1001     Rahul  22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran  31        M  Marketing     NaN    Calicut
# 2          1003       Anu  30        F      Sales  48,000    Unknown
# 3          1004      John  27        F  Marketing   35000    Calicut
# 4          1005     Aisha  25  Unknown         IT  48,000    Unknown
# ..          ...       ...  ..      ...        ...     ...        ...
# 95         1096       Anu  27     Male      Sales   42000      kochi
# 96         1097  Mohammed  29     Male         HR   35000    Unknown
# 97         1098       Anu  22     Male         HR     NaN    Unknown
# 98         1099     Arun   22   Female         IT   42000      Kochi
# 99         1100      Sara  31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# 1   2023-01-15     Unknown      invalidemail
# ...

# %%
df["Age"] = pd.to_numeric(df["Age"]) 
df
# Out:
#     Employee_Id      Name  Age   Gender Department  Salary       City  \
# 0          1001     Rahul   22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran   31        M  Marketing     NaN    Calicut
# 2          1003       Anu   30        F      Sales  48,000    Unknown
# 3          1004      John   27        F  Marketing   35000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48,000    Unknown
# ..          ...       ...  ...      ...        ...     ...        ...
# 95         1096       Anu   27     Male      Sales   42000      kochi
# 96         1097  Mohammed   29     Male         HR   35000    Unknown
# 97         1098       Anu   22     Male         HR     NaN    Unknown
# 98         1099     Arun    22   Female         IT   42000      Kochi
# 99         1100      Sara   31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df.dtypes
# Out:
# Employee_Id     int64
# Name              str
# Age             int64
# Gender            str
# Department        str
# Salary         object
# City              str
# Joindate          str
# Performance       str
# Email             str
# dtype: object

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df
# Out:
#     Employee_Id      Name  Age   Gender Department  Salary       City  \
# 0          1001     Rahul   22   Female    Unknown   55000  Bangalore
# 1          1002     Kiran   31        M  Marketing     NaN    Calicut
# 2          1003       Anu   30        F      Sales  48,000    Unknown
# 3          1004      John   27        F  Marketing   35000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48,000    Unknown
# ..          ...       ...  ...      ...        ...     ...        ...
# 95         1096       Anu   27     Male      Sales   42000      kochi
# 96         1097  Mohammed   29     Male         HR   35000    Unknown
# 97         1098       Anu   22     Male         HR     NaN    Unknown
# 98         1099     Arun    22   Female         IT   42000      Kochi
# 99         1100      Sara   31   Female        IT    55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df["Salary"] = df["Salary"].astype(str)
df["Salary"] = df["Salary"].str.replace(",", "", regex=False)
df
# Out:
#     Employee_Id      Name  Age   Gender Department Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000  Bangalore
# 1          1002     Kiran   31        M  Marketing    NaN    Calicut
# 2          1003       Anu   30        F      Sales  48000    Unknown
# 3          1004      John   27        F  Marketing  35000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000    Unknown
# ..          ...       ...  ...      ...        ...    ...        ...
# 95         1096       Anu   27     Male      Sales  42000      kochi
# 96         1097  Mohammed   29     Male         HR  35000    Unknown
# 97         1098       Anu   22     Male         HR    NaN    Unknown
# 98         1099     Arun    22   Female         IT  42000      Kochi
# 99         1100      Sara   31   Female        IT   55000    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# 1   2023-01-15     Unknown      invalidemail
# ...

# %%
df["Salary"] = pd.to_numeric(df["Salary"]) 
df
# Out:
#     Employee_Id      Name  Age   Gender Department   Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.0  Bangalore
# 1          1002     Kiran   31        M  Marketing      NaN    Calicut
# 2          1003       Anu   30        F      Sales  48000.0    Unknown
# 3          1004      John   27        F  Marketing  35000.0    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.0    Unknown
# ..          ...       ...  ...      ...        ...      ...        ...
# 95         1096       Anu   27     Male      Sales  42000.0      kochi
# 96         1097  Mohammed   29     Male         HR  35000.0    Unknown
# 97         1098       Anu   22     Male         HR      NaN    Unknown
# 98         1099     Arun    22   Female         IT  42000.0      Kochi
# 99         1100      Sara   31   Female        IT   55000.0    Unknown
#
#       Joindate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df.dtypes
# Out:
# Employee_Id      int64
# Name               str
# Age              int64
# Gender             str
# Department         str
# Salary         float64
# City               str
# Joindate           str
# Performance        str
# Email              str
# dtype: object

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
#       Joindate Performance             Email
# ...

# %%
df["Joindate"] = df["Joindate"].str.replace("/", "-", regex=False)
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
#       Joindate Performance             Email
# ...

# %%
df["Joindate"] = df["Joindate"].fillna(df["Joindate"].mode()[0])
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
#       Joindate Performance             Email
# ...

# %%
df["City"]=df["City"].str.title()
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      Kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
#       Joindate Performance             Email
# ...

# %%
df["Performance"]=df["Performance"].str.title()
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      Kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
#       Joindate Performance             Email
# ...

# %%
df["Performance"].unique()
# Out:
# <StringArray>
# ['Good ', 'Unknown', 'Good', 'Excellent', 'Poor']
# Length: 5, dtype: str

# %%
df["Employee_Id"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Employee_Id, Length: 100, dtype: bool

# %%
df["salary_category"] = df["Salary"].apply(
    lambda x: "Low" if x < 40000 else "Medium" if x < 50000 else "High"
)
df
# Out:
#     Employee_Id      Name  Age   Gender Department        Salary       City  \
# 0          1001     Rahul   22   Female    Unknown  55000.000000  Bangalore
# 1          1002     Kiran   31        M  Marketing  45766.233766    Calicut
# 2          1003       Anu   30        F      Sales  48000.000000    Unknown
# 3          1004      John   27        F  Marketing  35000.000000    Calicut
# 4          1005     Aisha   25  Unknown         IT  48000.000000    Unknown
# ..          ...       ...  ...      ...        ...           ...        ...
# 95         1096       Anu   27     Male      Sales  42000.000000      Kochi
# 96         1097  Mohammed   29     Male         HR  35000.000000    Unknown
# 97         1098       Anu   22     Male         HR  45766.233766    Unknown
# 98         1099     Arun    22   Female         IT  42000.000000      Kochi
# 99         1100      Sara   31   Female        IT   55000.000000    Unknown
#
# ...

# %%
df.dtypes
# Out:
# Employee_Id          int64
# Name                   str
# Age                  int64
# Gender                 str
# Department             str
# Salary             float64
# City                   str
# Joindate               str
# Performance            str
# Email                  str
# salary_category        str
# dtype: object
