# %%
import  pandas as pd
movie=[
       [101, "Inception", "Sci-Fi", 8.8, 2010],
    [102, "Avatar", "Action", 7.9, 2009],
    [103, "Titanic", "Romance", 7.9, 1997],
    [104, "Joker", "Drama", 8.4, 2019]
    
]
df=pd.DataFrame(movie,columns=['Movie_id','Movie_name','Genre','Rating','Release_Year '])
df
# Out:
#    Movie_id Movie_name    Genre  Rating  Release_Year
# 0       101  Inception   Sci-Fi     8.8           2010
# 1       102     Avatar   Action     7.9           2009
# 2       103    Titanic  Romance     7.9           1997
# 3       104      Joker    Drama     8.4           2019

# %%
movie={'Movie_id':[101,102,103,104],
       'Movie_name':['Inception','Avatar','Titanic','Joker'],
       'Genre':['Sci-Fi','Action','Romance','Drama'],
       'Rating':[8.8,7.9,7.9,8.4],
       'Release_Year':[2010,2009,1997,2019]
      }
df=pd.DataFrame(movie)
df
# Out:
#    Movie_id Movie_name    Genre  Rating  Release_Year
# 0       101  Inception   Sci-Fi     8.8          2010
# 1       102     Avatar   Action     7.9          2009
# 2       103    Titanic  Romance     7.9          1997
# 3       104      Joker    Drama     8.4          2019

# %%
movie= [
    {"Movie_ID": 101, "Movie_Name": "Inception", "Genre": "Sci-Fi", "Rating": 8.8, "Release_Year": 2010},
    {"Movie_ID": 102, "Movie_Name": "Avatar", "Genre": "Action", "Rating": 7.9, "Release_Year": 2009},
    {"Movie_ID": 103, "Movie_Name": "Titanic", "Genre": "Romance", "Rating": 7.9, "Release_Year": 1997},
    {"Movie_ID": 104, "Movie_Name": "Joker", "Genre": "Drama", "Rating": 8.4, "Release_Year": 2019}
]
df=pd.DataFrame(movie)
df
# Out:
#    Movie_ID Movie_Name    Genre  Rating  Release_Year
# 0       101  Inception   Sci-Fi     8.8          2010
# 1       102     Avatar   Action     7.9          2009
# 2       103    Titanic  Romance     7.9          1997
# 3       104      Joker    Drama     8.4          2019

# %%
tit=pd.read_csv(r"C:\Users\ANSHIKA\Downloads\Titanic-Dataset.csv")
df
# Out:
#    Movie_ID Movie_Name    Genre  Rating  Release_Year
# 0       101  Inception   Sci-Fi     8.8          2010
# 1       102     Avatar   Action     7.9          2009
# 2       103    Titanic  Romance     7.9          1997
# 3       104      Joker    Drama     8.4          2019

# %%
tit.ndim
# Out:
# 2

# %%
tit.shape
# Out:
# (891, 12)

# %%
tit.size
# Out:
# 10692

# %%
tit.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
tit.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
tit.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
tit.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
tit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe(include='object')
# Out:
# C:\Users\ANSHIKA\AppData\Local\Temp\ipykernel_13764\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#        Movie_Name   Genre
# count           4       4
# unique          4       4
# top     Inception  Sci-Fi
# freq            1       1

# %%
df.describe()
# Out:
#          Movie_ID   Rating  Release_Year
# count    4.000000  4.00000      4.000000
# mean   102.500000  8.25000   2008.750000
# std      1.290994  0.43589      9.032349
# min    101.000000  7.90000   1997.000000
# 25%    101.750000  7.90000   2006.000000
# 50%    102.500000  8.15000   2009.500000
# 75%    103.250000  8.50000   2012.250000
# max    104.000000  8.80000   2019.000000

# %%
tit.iloc[1:][['PassengerId','Name','Age','Sex','Survived']]
# Out:
#      PassengerId                                               Name   Age  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2              3                             Heikkinen, Miss. Laina  26.0
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5                           Allen, Mr. William Henry  35.0
# 5              6                                   Moran, Mr. James   NaN
# ..           ...                                                ...   ...
# 886          887                              Montvila, Rev. Juozas  27.0
# 887          888                       Graham, Miss. Margaret Edith  19.0
# 888          889           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889          890                              Behr, Mr. Karl Howell  26.0
# 890          891                                Dooley, Mr. Patrick  32.0
#
#         Sex  Survived
# 1    female         1
# 2    female         1
# ...

# %%
df.iloc[5:16]
# Out:
# Empty DataFrame
# Columns: [Movie_ID, Movie_Name, Genre, Rating, Release_Year]
# Index: []

# %%
df.loc[20:30, ['Name', 'Fare']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df.loc[20:30, ['Name', 'Fare']]
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
# ...

# %%
tit.iloc[1:11]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df.iloc[-5:]

# %%
df.iloc[3:13]
# Out:
#    Movie_ID Movie_Name  Genre  Rating  Release_Year
# 3       104      Joker  Drama     8.4          2019

# %%
df.iloc[1:5]

# %%
tit["Family_Size"] = tit["SibSp"] + tit["Parch"]
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
