# %%
import pandas as pd
student=pd.read_excel(r"C:\Users\ANSHIKA\Downloads\student_performance_dataset_34227614.xlsx")
student
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
student.sort_values(by='final_exam_score',ascending=False).head(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 381         382  Female               6.2                83.2          7.3
# 383         384    Male               6.2                90.5          6.6
# 387         388    Male               5.0                86.9          4.9
# 312         313  Female               4.9                90.1          7.5
# 314         315    Male               2.7                88.5          7.3
# 315         316  Female               5.1                89.9          8.1
# 934         935  Female               3.6                89.4          7.0
# 42           43  Female               5.1                82.8          8.1
# 50           51    Male               5.9                82.5          6.6
# 948         949  Female               3.7                93.9          8.5
#
#     parental_education internet_access extracurricular_activities  \
# 381                PhD             Yes                         No
# ...

# %%
student['parental_education'].unique()
# Out:
# <StringArray>
# ['Bachelors', 'High School', nan, 'Masters', 'PhD']
# Length: 5, dtype: str

# %%
print(student.iloc[10:21][['gender','student_id','previous_grade','final_exam_score']])
# Out:
#     gender  student_id  previous_grade  final_exam_score
# 10    Male          11            73.4              68.9
# 11    Male          12            37.9              76.7
# 12    Male          13            49.0              82.6
# 13    Male          14            67.9              93.3
# 14  Female          15            71.0              73.9
# 15    Male          16            65.6              84.8
# 16  Female          17            51.0              81.5
# 17  Female          18            60.2              75.5
# 18  Female          19            74.7              89.7
# 19    Male          20            77.0              92.8
# 20  Female          21            69.8              73.5

# %%
student[student['gender'] == 'female'][['gender', 'previous_grade', 'final_exam_score', 'final_grade']]
# Out:
# Empty DataFrame
# Columns: [gender, previous_grade, final_exam_score, final_grade]
# Index: []

# %%
student1=student.copy()
student1
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
student['final_exam_score'] = student['final_exam_score'].astype(float)

# %%
print(student['final_exam_score'].dtype)
# Out:
# float64

# %%
student = student.drop('sleep_hours', axis=1)
student
# Out:
#      student_id  gender  study_time_hours  attendance_percent  \
# 0             1    Male               4.0                98.0
# 1             2  Female               6.3               100.0
# 2             3    Male               4.9                85.3
# 3             4    Male               2.6                77.5
# 4             5    Male               2.2                89.6
# ..          ...     ...               ...                 ...
# 995         996    Male               2.8                75.4
# 996         997    Male               6.7                88.4
# 997         998  Female               2.6                84.5
# 998         999  Female               4.6                85.3
# 999        1000    Male               3.9                77.4
#
#     parental_education internet_access extracurricular_activities  \
# 0            Bachelors             Yes                        Yes
# 1          High School             Yes                        Yes
# ...

# %%
print(student.sort_values(by='final_grade', ascending=False)[['gender', 'final_exam_score', 'parental_education']])
# Out:
#      gender  final_exam_score parental_education
# 760  Female              53.2        High School
# 539  Female              57.3          Bachelors
# 715  Female              54.1        High School
# 364    Male              57.4          Bachelors
# 136    Male              59.7        High School
# ..      ...               ...                ...
# 635  Female              96.3        High School
# 628    Male              93.9            Masters
# 626    Male              96.8        High School
# 154    Male              95.4          Bachelors
# 0      Male             100.0          Bachelors
#
# [1000 rows x 3 columns]

# %%
student = student.drop('part_time_job', axis=1)

print(student.iloc[:15])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 student = student.drop('part_time_job', axis=1)
#       2
#       3 print(student.iloc[:15])
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
student['final_exam_score'] = student['final_exam_score'].astype(float)

print(student.loc[student['final_exam_score'] > 80])
# Out:
#      student_id  gender  study_time_hours  attendance_percent  \
# 0             1    Male               4.0                98.0
# 1             2  Female               6.3               100.0
# 2             3    Male               4.9                85.3
# 3             4    Male               2.6                77.5
# 5             6  Female               4.2                78.2
# ..          ...     ...               ...                 ...
# 990         991  Female               2.5                81.4
# 991         992  Female               5.1                71.7
# 993         994  Female               6.2                87.6
# 996         997    Male               6.7                88.4
# 998         999  Female               4.6                85.3
#
#     parental_education internet_access  previous_grade  final_exam_score  \
# 0            Bachelors             Yes            76.9             100.0
# ...

# %%
# Second DataFrame
school = pd.DataFrame({
    "gender": ["female", "male"],
    "Scholarship": ["Yes", "No"]
})

# Merge the DataFrames
merged = pd.merge(student, school, on="gender")

print(merged)
# Out:
# Empty DataFrame
# Columns: [student_id, gender, study_time_hours, attendance_percent, parental_education, internet_access, previous_grade, final_exam_score, final_grade, Scholarship]
# Index: []
