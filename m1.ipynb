# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel(r"C:\Users\ANSHIKA\Downloads\c4fe3a02-800a-48ae-b5bc-15bbc219f46a.xlsx")
df
# Out:
#        Month  Sales  Expenses  Profit  Customers
# 0    January  45000     30000   15000        120
# 1   February  52000     32000   20000        135
# 2      March  48000     31000   17000        128
# 3      April  60000     35000   25000        150
# 4        May  65000     38000   27000        165
# 5       June  58000     36000   22000        145
# 6       July  72000     40000   32000        180
# 7     August  68000     39000   29000        172
# 8  September  75000     42000   33000        190
# 9    October  80000     45000   35000        205

# %%
from matplotlib.lines import lineStyles
plt.figure(figsize=(15,5))
plt.plot(df["Month"],df["Sales"],color="blue",linestyle='--')
plt.title("Month and sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
plt.bar(df["Month"],df["Profit"],color="green")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.show()

# %%
plt.pie(df["Profit"],labels=df["Month"])
plt.show()

# %%
plt.scatter(df["Customers"],df[Sales)
plt.xlabel("Customers")
plt.ylabel("Sales")
plt.title("Customers and sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.scatter(Customers,Sales)
#       2 plt.xlabel("Customers")
#       3 plt.ylabel("Sales")
#       4 plt.title("Customers and sales")
#
# NameError: name 'Customers' is not defined
